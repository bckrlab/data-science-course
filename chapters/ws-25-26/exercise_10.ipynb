# %% [markdown]
# ---
# authors:
#   - name: Tom Siegl
# ---

# %% [markdown]
# # 10: Approximate Bayesian Inference

# %% [markdown]
# ## Setup

# %% [markdown]
# :::{important} Tasks
# 1. Open >>[this binder](https://mybinder.org/v2/git/https%3A%2F%2Fgitlab.elaine.uni-rostock.de%2Fkb637%2Fabcworkshop/HEAD)<<. (It is based on >>[this repository](https://gitlab.elaine.uni-rostock.de/kb637/abcworkshop)<<.)
# 2. Create a new notebook file called `install.ipynb` and open it.
# 3. Add a code cell and paste `%pip install pyabc` into it.
# 4. Run that code cell. (This installs the pyABC package into the current environment.)
# :::

# %% [markdown]
# ## Parameter Inference

# %% [markdown]
# ### Setup

# %% [markdown]
# :::{important} Tasks
# 1. Go to the `scripts` directory.
# 2. Create a new notebook file called `1.ipynb` and open it.
# 3. Add a code cell and copy the code from `1ParameterInference.py` into it.
# 4. Import numpy as `np` and replace `sp.randn` with `np.random.randn`. (This function is not available in the current scipy version.)
# :::

# %% [markdown]
# ### Main Tasks

# %% [markdown]
# :::{important} Tasks
# 1. Go to the `presentation` directory and open the PDF.
# 2. Go to slide 12 and work on the tasks. (Instead of running the script file, you can run the notebook that you have just prepared.)
# :::

# %% [markdown]
# :::{tip} Your answer
# :class:dropdown
# 1.
# :::

# %% [markdown]
# ## Parameter Inference for a Physical Model

# %% [markdown]
# ### Setup

# %% [markdown]
# :::{important} Tasks
# 1. Go to the `scripts` directory.
# 2. Create a new notebook file called `2.ipynb` and open it.
# 3. Add a code cell and copy the code from `2ParameterInference_PhysicalModel.py` into it.
# 4. Import numpy as `np` and replace
#     - `sp.array` with `np.array`
#     - `sp.randn` with `np.random.randn`
#     - `sp.absolute` with `np.abs`
# :::

# %% [markdown]
# ### Main Tasks

# %% [markdown]
# :::{important} Tasks
# 1. Go to the `presentation` directory and open the PDF.
# 2. Go to slide 13 and work on the tasks. (Instead of running the script file, you can run the notebook that you have just prepared.)
# :::

# %% [markdown]
# :::{tip} Your answer
# :class:dropdown
# 1.
# :::

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ### Setup

# %% [markdown]
# :::{important} Tasks
# 1. Go to the `scripts` directory.
# 2. Create a new notebook file called `3.ipynb` and open it.
# 3. Add a code cell and copy the code from `3ModelSelection.py` into it.
# :::

# %% [markdown]
# ### Main Tasks

# %% [markdown]
# :::{important} Tasks
# 1. Run the notebook that you have just prepared.
# 2. Explain how ABC is used for model selection.
# :::

# %% [markdown]
# :::{tip} Your answer
# :class:dropdown
# 1.
# :::
